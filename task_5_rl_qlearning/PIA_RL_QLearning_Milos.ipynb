# %% [markdown]
# # PIA - Reinforcement Learning
#
# 1. RL Intro
# 2. Dynamic Programing
# 3. **Tabular Q-Learning**
# 4. Deep Reinforcement Learning (DQN)
#
# ## 3. Tabular Q-Learning
#
# In this notebook you will solve the full reinforcement learning problem by implementing the well-known Q-Learning algorithm. *Full problem* means that the agent will learn from samples instead of using a world model, i.e the agent will learn to solve the task without prior knowledge.

# %% [markdown]
# ---
# ### Course of Action
#
# * Please write all executable python code in ```Code```-Cells (```Cell```->```Cell Type```->```Code```) and all Text as [Markdown](http://commonmark.org/help/) in ```Markdown```-Cells
# * Describe your thinking and your decisions (where appropriate) in an extra Markdown Cell or via Python comments
# * In general: discuss all your results and comment on them (are they good/bad/unexpected, could they be improved, how?, etc.). Furthermore, visualise your data (input and output).
# * Write a short general conclusion at the end of the notebook
# * Further experiments are encouraged. However, don't forget to comment on your reasoning.
# * Use a scientific approach for all experiments (i.e. develop a hypothesis or concrete question, make observations, evaluate results)
#
# ### Submission
#
# Upload the complete Notebook (and an exported html version) to Ilias before the deadline. One Notebook per Group is enough. Edit the teammember table below.
#
# **Important**: Also attach a HTML version of your notebook (```File```->```Download as```->```HTML```) in addition to the ```.ipynb```-File.

# %% [markdown]
# | Teammember |                    |
# |------------|--------------------|
# | 1.         | Geoffrey Hinton    |
# | 2.         | Yoshua Bengio      |
# | 3.         | Yann LeCun         |
# | 4.         | Jürgen Schmidhuber |
# ---

# %% [markdown]
# ## Prerequisites
#
# - The notebook is pretty self contained and includes all relevant theory. However, make sure that you have **read** and *understood* a corresponding lecture at least once! The notebook can only provide a short recap. Being prepared will help you to finish the notebook in time!
# - Some good reading resources are:
#
#     1. Johannes Maucher's [lecture on RL](https://gitlab.mi.hdm-stuttgart.de/maucher/ML/tree/master/Slides/V12Reinforcement.pdf) - chapter 4.
#     2. David Silver's course on RL: [Lecture 4](https://www.davidsilver.uk/teaching/): [Youtube](https://www.youtube.com/watch?v=PnHCvfgC_ZA), [Lecture 5](https://www.davidsilver.uk/teaching/): [Youtube](https://www.youtube.com/watch?v=0g4j2k_Ggc4).
#     3. Sutton & Barto: [Reinforcement Learning: An Introduction](http://incompleteideas.net/book/the-book-2nd.html) chapter 6.4 & 6.5 (complete online pdf draft available).

# %% [markdown]
# ## Theory
#
# In the last notebook you have implemented **Policy Iteration** with **Dynamic Programming** as your first RL algorithm. This was an optimal solution but you will rarely see DP applied to real world problems. Even though those methods are guaranteed to converge with probability 1 to an optimal policy, they suffer from two major drawbacks.
#
# ---
# ### Curse of dimensionality
#
# The first one is the so called **curse of dimensionality**, meaning that the computational requirements often grow exponentially with the number of state variables. Think of our policy array that we just created. It should be clear that this approach does not scale to a very high number of states/actions, which is the case in almost every real world problem. In such situations, even one update swipe through the entire state and action space can be computationally infeasible. Later we will see how to tackles this problem with **function approximation**.
#
# ### Planning vs. Learning
#
# The second problem is that we have *cheated* in the last part. More precicely, we have created a **world model** from the knowledge that we had about the grid world. While this was pretty easy in our case, it is very unlikely that you have that much knowledge about a real world environment. Or, that the underlying environment dynamics are given by a very complicated probability distribution that we don't know (or just can't model). In consequence, we can not simply calculate the expectation values for $V(s)$ or $Q(s,a)$. This is not possible since the expectation sum requires the knowledge of the state transition probabilities $\mathcal{P}$ and the reward function $\mathcal{R}$. If we don't have such a model, the next best thing we can do is to simply **learn from trial an error**, e.g. by interacting with the environment and see what happens. If this limitation sounds reasonable to you, welcome to **reinforcement learning**!
#
# ### Value based, model free RL
#
# > In the following, we will solve the **full reinforcement learning problem** by **learning** an **estimate of the value function** from **experience**.
#
# Now instead of *simulating* the outcome of actions through a world model, the agent has to actually **interact** with the environment in order to produce new experience, i.e. gather training data. Although we are **learning** now from this data instead of *planning* ahead, we will stay with the idea of a value function. All RL algorithms that use the concept of a value function are called **value based**. Furthermore, since we assume, and have, no model of the environment, we are in the realm of **model free** reinforcement learning.
#
#
# > Note that there is also a class of so called **model based** algorithms in the RL literature. However, these algorithms **do not have or assume a perfect world model** either but instead, try to learn the underlying dynamics and transition probabilities. Sometimes, in addtion to a value function and/or policy. The general idea is then to use this **imperfect model** again to *plan ahead* and *simulate* potential outcomes of actions even though the model is not entirely correct.
#
# <img src="./RL_pics/RL_taxonomy.png" alt="Agent-Environment-Loop" style="width: 400px;"/>

# %% [markdown]
# ---
#
# ### Learning from Samples
#
# Recall that within the Policy Iteration framework, we have calculated the **expected return**. We did so by decomposing the return into the immediate reward plus the discounted value of the expected next state or state-action pair. For the action-value function $Q(s,a)$ this has the form (*Bellman Expectation Equation*):
#
# $$\begin{eqnarray}
# Q_{\pi}(s,a) &=& \mathbb{E}\Big[R_{t+1} + \gamma Q_{\pi}(S_{t+1},A_{t+1}) \mid S_t=s, A_t=a\Big]
# \end{eqnarray}$$
#
# Since the calculation of the **expectation** $\mathbb{E}$, requires us to sum over all possible outcomes and hence, requires knowledge about the state transition probabilities $\mathcal{P}$ and the reward function $\mathcal{R}$, we can't do this anymore. Instead, we have to learn from experience produced within the agent-environment loop.
#
# <img src="./RL_pics/AgentEnvLoop.png" alt="Agent-Environment-Loop" style="width: 400px;"/>
#
# By interacting with the environment, an agent will produce *training data* in the form of state transition tuples $(S_t,A_t,R_{t+1},S_{t+1})$. Now instead of calculating the full expectation, we can use those tuples to calculate an **estimate of the true value function** by using them similarly to the Bellman Expectation Equation:
#
# $$\begin{eqnarray}
# Q_{\pi}(s,a) &=& r_{t+1} + \gamma Q_{\pi}(s_{t+1},a_{t+1})
# \end{eqnarray}$$
#
# Think of the concrete $(s,a,r,s')$ tuples as distinct *samples*, drawn from the underlying probability distributions $\mathcal{P}$ and $\mathcal{R}$. If we can update $Q$ many times and with a *sufficient number* of distinct samples, our estimate will get closer to the true value function. This is the idea behind the so called **SARSA** algorithm (short for s,a,r,s',a'). However, SARSA does not apply the Bellman Expectation update directly but instead, uses a *softer* update rule. Because all Q-values are only estimates, it is better to not apply the full update $r_{t+1} + \gamma Q(s_{t+1},a_{t+1})$ but rather use it as a **target** towards which we will update the old estimate. The complete idea is thereby to **take the old estimate** $Q(s,a)$ and **update it** only **a little bit towards the difference between old and new estimate**. Formally the update rules is given by:
#
# $$\begin{eqnarray}
# Q(s_t, a_t) \leftarrow Q(s_t, a_t) + \alpha \left[ \underbrace{r_{t+1} + \gamma Q(s_{t+1}, a_{t+1})}_{target} - \underbrace{Q(s_t, a_t)}_{current} \right]
# \end{eqnarray}$$
#
# where $\alpha$ is a small learning rate $0 < \alpha \leq 1$ and the full expression in square brackets is called the **TD-Error** (TD for Temporal-Difference). Such updates are called **on-policy** because the **same policy** was used to produce the sample and to choose the Q-value which to backup, i.e. to choose $a_{t+1}$ in $s_{t+1}$. Using this update rule, an agent can evaluate a given policy if it visits ~~every~~ enough state-action pairs multiple times. We can then improve the policy like in Policy Iteration and will finally arrive at an optimal policy after enough iterations.

# %% [markdown]
# ---
# ### Q-Learning
#
# As it turns out, there exists a very similar update that enables us to **improve the policy directly**. This is known as **Q-Learning**. Compare the new **target** expression to the SARSA target:
#
# $$\begin{eqnarray}
# Q(s_t, a_t) \leftarrow Q(s_t, a_t) + \alpha \left[ \underbrace{r_{t+1} + \gamma \max_a Q(s_{t+1}, a)}_{target} - \underbrace{Q(s_t, a_t)}_{current} \right]
# \end{eqnarray}$$
#
# This is an **off-policy** update now because $r_{t+1}$ and $s_{t+1}$ are produced by the policy that we are following right now (**behavior policy**), but in the target, we always back up a Q-value according to a second, so called **target policy**, in this case a greedy **max** policy. Using such updates, we could for instance follow a random behavior policy to explore the environment (try out all states and actions) while improve at the same time with the greedy max policy. This is good because when learning from samples, it is crucial to visit *every* (ideally it should be every) state-action pair at least once, but as many times as possible in order to get a decent estimate of the value function. Evaluating such an exploration policy and improving on it at the same time (in one step), makes the update much more efficient compared to the SARSA algorithm.
#
# However, we still need to **improve the behavior policy** over time in order to find an optimal policy. Because we are learning from samples, we first want to make sure that the agent has visited *enough* distinct state-action pairs before improving greedily. Otherwise we may ignore some potentially very good states and actions, only because the agent just has't seen them and therefore, we can't take them into account when improving the policy. On the other hand, we don't want to explore forever. This tradeoff between exploration and exploitation is know as the **exploration-exploitation** dilemma. The most common approach for balancing between these two is the **$\epsilon$-greedy policy**.

# %% [markdown]
# ---
# ### E-Greedy Policy
#
# The idea is very simple. In order to explore in the beginning and converge to an optimal policy over time, we will start with a fully random policy and slowly transition to a greedy max policy. This is what the $\epsilon$-greedy policy does. With probability $\epsilon$ select a random action, with probability $1 - \epsilon$ select the best action so far. We can now control the transition by starting with $\epsilon = 1$ and slowly decay it over $n$ time steps until we arrive at an almost fully greedy policy. Formally this can we written as:
#
# $$\begin{eqnarray}
# a = \begin{cases}
#         \text{a random action}                             & \text{ with probability } \epsilon\\
#         \\
#         \arg \displaystyle \max_{a \in \mathcal{A}} Q(s,a) & \text{ with probability } 1-\epsilon
#     \end{cases}
# \end{eqnarray}$$
#
# *Almost* fully greddy, because we want the policy to be **greedy in the limit with infinite exploration**, which is a property that does provides us some nice convergence guarantees. In practice, this simply means that we will fix $\epsilon$ to some small value $\epsilon_n > 0$ after time step $n$.

# %% [markdown]
# ---
# ## Implementation
#
# Now that we have covered the necessary theory, let's start with the implementation of Q-Learning. Like in the last notebook, we will first implement some helper functions to keep the final loop clean and understandable. Also, as in the last notebook, we provide a set of plotting functions for you but this time, adjusted for Q-values. In addition, there is a `plot_agent` function which draws the agents current position on top of the value function or policy. Here is a list of functions that you have to provide in the following. For each, we added relevant comments right before the corresponding code cells.
#
# ###### Provided by us:
# - `plot_value_function`, `plot_policy`, `  plot_agent`, `plot_things`
# - `get_current_state`, function that returns the current state of an agent given a raw observation.
#
# ###### To be implemented:
# - `Q`, Q-Value function
# - `choose_egreedy_action`, e-greedy policy
# - `update`, Q-learning update for the value function
# - basic agent-env loop
# - a linear decay schedule for epsilon
#
# Finally combine everything to the Q-Learning algorithm, i.e. implement a Q-Learning agent. :)
#
# ---

# %% [markdown]
# ##### Plotting functions
#
# These are almost the same functions as in the last notebook. Note that `plot_value_function` now takes an **action value function** and **recovers** the **state value function** by summing over all action values in one state. This makes the visualisation more clean. On the downside you can't directly relate those values to the policy anymore. If you want more detailed plotting, e.g. per action value, feel free to modify the code to your needs.
#
# In addition, the policy plot now only takes the action values as argument and will plot a greedy policy from there directly. This is because we don't need to store an explicit policy anymore as you will see below.
#
# In general, use the plotting functions as you please.

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import patches
from IPython import display
sns.set_style("darkgrid")

def plot_value_function(Q, print_values=True):
        
    # recover V from Q by summing over all action values per state
    V = np.sum(Q, axis=2)
    # V = np.max(Q, axis=2)
  
    ax = sns.heatmap(V, vmin=-1.5, vmax=1.5, annot=print_values, 
                        xticklabels=True, yticklabels=True, 
                        square=True, linewidths=.5,  
                        cmap=sns.diverging_palette(10, 220, sep=40, n=256))  
    return ax

def plot_agent(ax, agent_state):
    # agent_state should be a tuple, e.g. (1,1) or (0,1) etc.
    col, row = agent_state[1],agent_state[0]
    ax.add_patch(patches.Rectangle((col, row), 1, 1, zorder=2))
    return ax

def plot_policy(Q, action_set):
    # plot the value funtion as a background
    ax = plot_value_function(Q, print_values=False)
    
    # plot a greedy policies actions in a quiver arrow plot
    num_rows, num_cols, num_actions = Q.shape
    
    for row in range(num_rows):
        for col in range(num_cols):
            state = (row,col)
            actions = np.where(Q[state] == max(Q[state]))[0]
            probability = 1 / len(actions)
            
            for action in actions:
                # Note that action directions and array indices are [row,col] based which corresponds to [y,x] in 
                # cartesian coordinates. Quiver plot works with cartesian coordiantes!
                # Note further that the sns heatmap plot has inverted the y axis which is fine as long as we are
                # adding our arrows to the same axis.
                move_y, move_x = action_set[action]
                length = 2 + 2 * (1 - probability)
                ax.quiver(col+0.5, row+0.5, move_x, move_y, angles='xy', scale_units='xy',zorder=10, scale=length)
             
    return ax

def plot_things(Q, action_set, agent_state=None):

    plt.close()
    fig = plt.figure(figsize=(13,4.5))
    
    # plot value function left
    fig.add_subplot(1,2,1)
    ax1 = plot_value_function(Q)
    if agent_state: plot_agent(ax1, agent_state)

    # plot policy right
    fig.add_subplot(1,2,2)
    ax2 = plot_policy(Q, action_set)
    if agent_state: plot_agent(ax2, agent_state)

# %% [markdown]
# For repainted instead of continuous cell output, use the following snippet **after** your plotting calls.
# ``` python
# plt.pause(0.1) # adjust time to your needs
# display.clear_output(wait=True)
# ```
#
# ---
#
# ##### Keep track of the agent's current state
# In order to update the correct Q-Values later, we need to know where the agent is *right now*, i.e. in which state it is. For that reason, we use the observation and perform a simple lookup of the player character, returning the agent's current state as tuple.

# %%
def get_current_state(observation):
    # get the player position from the observations layers, boolean matrix
    player_pos = np.nonzero(observation.layers['P'])
    row = int(player_pos[0])
    col = int(player_pos[1])
    
    # translate the position from world space to state space
    return (row - 1, col - 1)

# %%
from gridworlds import exitgames

# Init a new game
game = exitgames.make_game(level=0)
ui   = exitgames.get_notebook_ui()
obs, rew, _ = game.its_showtime()

# Get the agents current state from the observation
state = get_current_state(obs)

# Print and render the state
print("Player position in state space: (%s,%s)" % state)
ui.render(obs)
# Out:
# pygame 2.4.0 (SDL 2.26.4, Python 3.10.11)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# Player position in state space: (3,0)
# <pre style="line-height:1.1;">######
# #   E#
# # x  #
# #  x #
# #P   #
# ######

# %% [markdown]
# ---
# ##### Action-Value function
#
# This function should return a fresh `Q` of size $n \times n \times m$ where $n$ is the number of state rows and cols and $m$ is the number of actions. Initialize it all zeros. The code in the cell below will plot `Q` as a state value function and a greedy policy based on the Q-values. Note that we don't limit the actionset anymore because the agent has no knowlede about *reasonable* actions.

# %%
import numpy as np

def action_value_function(num_row, num_cols, num_actions):
    # Initialize the Q table
    Q = np.zeros((num_row, num_cols, num_actions))
    return Q

# %%
# Testing
Q = action_value_function(4,4,5)
plot_things(Q, game.get_action_set())

# %% [markdown]
# To see how the policy plot renders a greedy policy based on the Q-Values execute the cell bellow. Note that for simplicity, the value function plot sums the values of all actions per state. For that reason, seeing the relationship between the value function and policy plot may not be as straightforward as it was in the last notebook.

# %%
# set action LEFT (3) in state (0,2) to propability 1
Q[(0,2)][3] = 1
Q[(1,2)][3] = 1
Q[(3,0)][1] = 1

plot_things(Q, game.get_action_set())

# %% [markdown]
# ##### E-Greedy policy
#
# Here you will implement an e-greedy action selection which is basically our e-greedy policy. There is no need to store the policy in a separate array anymore because we can choose the best actions based on the Q-values array directly. Note that the function should take explicit values for epsilon as its third argument. The decay of epsilon will be handeled separately in the loop. Make sure that if there are multiple equally good actions, the greedy part should select randomly between them!
#
# Here are some functions you may find helpful for your implementation.
#
# - `numpy.random.random`, `numpy.random.randint` etc.
# - `numpy.random.choice` select a random value from an array
# - `numpy.where` will return a tuple of array(s), containing the indices of values that satisfy some condition. (In the case of a 1-D array, the tuple contains only 1 array for axis 0 etc.)
#
# Example:
# ```python
# x = np.array([1,2,3,1])
# one_indices = np.where(x==1)[0]
# print(one_indices)
# [0 3]
# ```
#
# Here is what you have to implement:
#
# $$\begin{eqnarray}
# a = \begin{cases}
#         \text{a random action}                             & \text{ with probability } \epsilon\\
#         \\
#         \arg \displaystyle \max_{a \in \mathcal{A}} Q(s,a) & \text{ with probability } 1-\epsilon
#     \end{cases}
# \end{eqnarray}$$

# %%
import numpy as np
from numpy import random as r
from random import randint
from random import choice
from numpy import where

# %%
def choose_egreedy_action(Q, state, epsilon):
    if np.random.random() < epsilon:
        # Choose a random action
        action = np.random.randint(Q.shape[2])
    else:
        # Choose the action with highest Q-value at current state
        # First, get all actions with the highest Q-value
        max_q_value = np.max(Q[state])
        max_q_actions = np.where(Q[state] == max_q_value)[0]
        # If multiple actions have the same max Q-value, choose randomly among them
        action = np.random.choice(max_q_actions)

    return action

# %% [markdown]
# ##### Update
#
# Finally you have to implement the update rule. The update should modify a specific Q-value in place and return nothing. Here again is the formula:
#
# $$\begin{eqnarray}
# Q(s_t, a_t) \leftarrow Q(s_t, a_t) + \alpha \left[ \underbrace{r_{t+1} + \gamma \max_a Q(s_{t+1}, a)}_{target} - \underbrace{Q(s_t, a_t)}_{current} \right]
# \end{eqnarray}$$

# %%
def update(Q, state, action, reward, next_state, gamma, alpha):
    if reward is None: reward = 0
    target = reward + gamma * np.max(Q[next_state])
    current = Q[state][action]
    Q[state][action] = current + alpha * (target - current)

# %%
update(Q, (0,2), 1, 1, (0,3), 0.9, 1)

# %%
plot_things(Q, game.get_action_set())

# %% [markdown]
# ### Build up from a basic agent-environment loop
#
# Great, now we can start implementing the Q-learning agent. For a clean approach, we suggest that you build up from a basic agent-environment and add the missing parts one by one. You dont have to read everything at once, just **work through the steps one by one** and come back after you have finished a task. You may want to proceed like this:
#
# 1. Reimplement or copy & paste a **basic agent-environment loop**. This loop should contain a random agent that can play **multiple episodes** of the game and reports the total reward **per episode**.<br><br>
#
# 2. Initialize a fresh **Q-value function** and use it with the **e-greedy action selection** in the loop. Start by using a fixed `epsilon = 1`. Note that you will need the agents current state which you can get from `get_current_state`. The agent is still fully random at this point.<br><br>
#
# 3. Implement a **decay schedule** for epsilon. The decay should be controllable with a `final_epsilon` value and a `final_exploration_step` value. After this final step (or if epsilon becomes too small), epsilon should be fixed to this final value. An easy way to verify your implementation is to keep track of epsilon with a list and plot it afterwards. Even though we deacy epsilon now, the agent is still fully random since we don't improve the policy yet.
# ```
# # While in the loop do something like: epsilon_schedule.append(epsilon)
# # After the training plot the schedule: plt.plot(epsilon_schedule), plt.show()
# ```
#
# 4. If everything is working so far, integrate the **Q-learning update** into the loop. The full Q-learning algorithm is given in a cell below. If you are unsure, use it to check when to do what inside the loop. Congratulations, after this point you have implemented your first (Q-learning) agent that is actually able to **learn** something! Next, you definetly want to gain some insight of what is really going on. Either you want to debug your code or you want to verify the results in a more scientific way. In any case, back and forth between task 4 and 5 as you need to.<br><br>
#
# 5. Verify what the agent is doing. You have several options ranging from visual feedback to more scientific approaches which you would use in a paper or thesis. Include at least some of them into your loop.
#     - **Visual feedback**: e.g. use `ui.render` and `time.sleep`.<br><br>
#     - **Live plot of Q and Pi**: e.g. use `plot_things` , `plt.pause` and `display.clear_output(wait=True)`.<br><br>
#     - **Data visualisation**: e.g. keep track of `episode_rewards`, `epsilon_schedule` etc. and plot them afterwards.
#
#     Note that the *live* plotting option can be very *slow*. If you run the agent for many episodes this will take some time. For that reason you may prefer to plot the value function and policy only every `n` steps or just after the training. If you still want to plot the Q-learning agent *live* and in action (which is cool to watch) you may prefer to replace the `%matplotlib inline` backend with a more performant backend like `osx, qt, gtk,` etc. For a list of backends execute `%matplotlib -l` on top of a cell. **NOTE: If you change the plotting backend, better restart the notebook.** Do not switch backends from cell to cell. This kind of works but may result in significant slow downs.

# %%
# Hyperparameters
epsilon = 0.1
gamma = 0.9
alpha = 0.1
min_epsilon = 0.01
decay_rate = 0.999

# %%
def agent_environment_loop(num_episodes, epsilon, final_epsilon, final_exploration_step, alpha, gamma):

    # Initialize the environment
    game = exitgames.make_game(level=1)
    ui   = exitgames.get_notebook_ui()

    # Initialize the Q table
    Q = action_value_function(game.state_space[0], game.state_space[1], game.action_space)

    # Initialize total rewards and epsilon schedule
    total_rewards = np.zeros(num_episodes)
    epsilon_schedule = []

    decay_rate = (epsilon - final_epsilon) / final_exploration_step

    for episode in range(num_episodes):
        # Initialize the game and get the initial state
        game = exitgames.make_game(level=0)
        obs, reward, done = game.its_showtime()
        episode_reward = 0

        while not game.game_over:

            # Get current state
            state = get_current_state(obs)

            # Choose action
            action = choose_egreedy_action(Q, state, epsilon)

            # Apply action to the game
            obs, reward, done = game.play(action)

            # Get next state
            next_state = get_current_state(obs)

            # Update Q
            update(Q, state, action, reward, next_state, gamma, alpha)

            # Accumulate reward
            episode_reward += reward if reward else 0

        # Decay epsilon
        epsilon = max(final_epsilon, epsilon - decay_rate)

        # Store total reward and epsilon
        total_rewards[episode] = episode_reward
        epsilon_schedule.append(epsilon)

        print(f"Episode {episode}: total reward = {episode_reward}, epsilon = {epsilon}")

    return Q, total_rewards, epsilon_schedule

# %%
Q, total_rewards, epsilon_schedule = agent_environment_loop(100, epsilon, min_epsilon, 100, alpha, gamma)
# Out:
# Episode 0: total reward = -4, epsilon = 0.09910000000000001
# Episode 1: total reward = 1, epsilon = 0.09820000000000001
# Episode 2: total reward = 1, epsilon = 0.09730000000000001
# Episode 3: total reward = 1, epsilon = 0.09640000000000001
# Episode 4: total reward = 1, epsilon = 0.09550000000000002
# Episode 5: total reward = 1, epsilon = 0.09460000000000002
# Episode 6: total reward = 1, epsilon = 0.09370000000000002
# Episode 7: total reward = 1, epsilon = 0.09280000000000002
# Episode 8: total reward = 1, epsilon = 0.09190000000000002
# Episode 9: total reward = 1, epsilon = 0.09100000000000003
# Episode 10: total reward = 0, epsilon = 0.09010000000000003
# Episode 11: total reward = 1, epsilon = 0.08920000000000003
# Episode 12: total reward = 1, epsilon = 0.08830000000000003
# Episode 13: total reward = 1, epsilon = 0.08740000000000003
# Episode 14: total reward = 1, epsilon = 0.08650000000000004
# Episode 15: total reward = 1, epsilon = 0.08560000000000004
# Episode 16: total reward = 1, epsilon = 0.08470000000000004
# Episode 17: total reward = 1, epsilon = 0.08380000000000004
# Episode 18: total reward = 1, epsilon = 0.08290000000000004
# Episode 19: total reward = 1, epsilon = 0.08200000000000005
# Episode 20: total reward = 1, epsilon = 0.08110000000000005
# Episode 21: total reward = 1, epsilon = 0.08020000000000005
# Episode 22: total reward = 1, epsilon = 0.07930000000000005
# Episode 23: total reward = 1, epsilon = 0.07840000000000005
# Episode 24: total reward = 1, epsilon = 0.07750000000000005
# Episode 25: total reward = 1, epsilon = 0.07660000000000006
# Episode 26: total reward = 1, epsilon = 0.07570000000000006
# Episode 27: total reward = 1, epsilon = 0.07480000000000006
# Episode 28: total reward = 1, epsilon = 0.07390000000000006
# Episode 82: total reward = 1, epsilon = 0.025300000000000145
# Episode 83: total reward = 1, epsilon = 0.024400000000000144
# Episode 84: total reward = 1, epsilon = 0.023500000000000142
# Episode 85: total reward = 1, epsilon = 0.02260000000000014
# Episode 86: total reward = 1, epsilon = 0.02170000000000014
# Episode 87: total reward = 1, epsilon = 0.020800000000000138
# Episode 88: total reward = 1, epsilon = 0.019900000000000136
# Episode 89: total reward = 1, epsilon = 0.019000000000000135
# Episode 90: total reward = 1, epsilon = 0.018100000000000133
# Episode 91: total reward = 1, epsilon = 0.017200000000000132
# Episode 92: total reward = 1, epsilon = 0.01630000000000013
# Episode 93: total reward = 1, epsilon = 0.01540000000000013
# Episode 94: total reward = 1, epsilon = 0.01450000000000013
# Episode 95: total reward = 1, epsilon = 0.013600000000000131
# Episode 96: total reward = 1, epsilon = 0.012700000000000131
# Episode 97: total reward = 1, epsilon = 0.011800000000000132
# Episode 98: total reward = 1, epsilon = 0.010900000000000132
# Episode 99: total reward = 1, epsilon = 0.010000000000000132

# %%
plot_things(Q, game.get_action_set())

# %%
# Call the function with appropriate parameters
Q, total_rewards, epsilon_schedule = agent_environment_loop(
    num_episodes=1000, 
    epsilon=1.0, 
    final_epsilon=0.01, 
    final_exploration_step=500, 
    alpha=0.1, 
    gamma=0.9
)

# Plot rewards and epsilon schedule
plt.figure(figsize=(12, 5))

plt.subplot(121)
plt.plot(total_rewards)
plt.xlabel('Episode')
plt.ylabel('Total Reward')

plt.subplot(122)
plt.plot(epsilon_schedule)
plt.xlabel('Episode')
plt.ylabel('Epsilon')

plt.tight_layout()
plt.show()
# Out:
# Episode 0: total reward = -14, epsilon = 0.99802
# Episode 1: total reward = -5, epsilon = 0.99604
# Episode 2: total reward = -3, epsilon = 0.99406
# Episode 3: total reward = -2, epsilon = 0.9920800000000001
# Episode 4: total reward = -11, epsilon = 0.9901000000000001
# Episode 5: total reward = -7, epsilon = 0.9881200000000001
# Episode 6: total reward = -9, epsilon = 0.9861400000000001
# Episode 7: total reward = -14, epsilon = 0.9841600000000001
# Episode 8: total reward = -5, epsilon = 0.9821800000000002
# Episode 9: total reward = 0, epsilon = 0.9802000000000002
# Episode 10: total reward = -4, epsilon = 0.9782200000000002
# Episode 11: total reward = -3, epsilon = 0.9762400000000002
# Episode 12: total reward = -6, epsilon = 0.9742600000000002
# Episode 13: total reward = -1, epsilon = 0.9722800000000003
# Episode 14: total reward = -8, epsilon = 0.9703000000000003
# Episode 15: total reward = -4, epsilon = 0.9683200000000003
# Episode 16: total reward = -19, epsilon = 0.9663400000000003
# Episode 17: total reward = -10, epsilon = 0.9643600000000003
# Episode 18: total reward = -10, epsilon = 0.9623800000000003
# Episode 19: total reward = -1, epsilon = 0.9604000000000004
# Episode 20: total reward = -19, epsilon = 0.9584200000000004
# Episode 21: total reward = 1, epsilon = 0.9564400000000004
# Episode 22: total reward = 0, epsilon = 0.9544600000000004
# Episode 23: total reward = -10, epsilon = 0.9524800000000004
# Episode 24: total reward = -4, epsilon = 0.9505000000000005
# Episode 25: total reward = -4, epsilon = 0.9485200000000005
# Episode 26: total reward = -6, epsilon = 0.9465400000000005
# Episode 27: total reward = -3, epsilon = 0.9445600000000005
# Episode 28: total reward = -3, epsilon = 0.9425800000000005
# Episode 29: total reward = -1, epsilon = 0.9406000000000005
# Episode 30: total reward = -3, epsilon = 0.9386200000000006
# Episode 31: total reward = 1, epsilon = 0.9366400000000006
# Episode 32: total reward = -8, epsilon = 0.9346600000000006
# Episode 33: total reward = -5, epsilon = 0.9326800000000006
# Episode 34: total reward = -2, epsilon = 0.9307000000000006
# Episode 35: total reward = -14, epsilon = 0.9287200000000007
# Episode 36: total reward = 0, epsilon = 0.9267400000000007
# Episode 37: total reward = -7, epsilon = 0.9247600000000007
# Episode 38: total reward = -1, epsilon = 0.9227800000000007
# Episode 39: total reward = -3, epsilon = 0.9208000000000007
# Episode 40: total reward = -3, epsilon = 0.9188200000000007
# Episode 41: total reward = -8, epsilon = 0.9168400000000008
# Episode 42: total reward = -1, epsilon = 0.9148600000000008
# Episode 43: total reward = 0, epsilon = 0.9128800000000008
# Episode 44: total reward = -4, epsilon = 0.9109000000000008
# Episode 45: total reward = -5, epsilon = 0.9089200000000008
# Episode 46: total reward = 0, epsilon = 0.9069400000000009
# Episode 47: total reward = -3, epsilon = 0.9049600000000009
# Episode 48: total reward = -5, epsilon = 0.9029800000000009
# Episode 49: total reward = -1, epsilon = 0.9010000000000009
# Episode 50: total reward = -3, epsilon = 0.8990200000000009
# Episode 51: total reward = -6, epsilon = 0.897040000000001
# Episode 52: total reward = -2, epsilon = 0.895060000000001
# Episode 53: total reward = 0, epsilon = 0.893080000000001
# Episode 54: total reward = 0, epsilon = 0.891100000000001
# Episode 55: total reward = 0, epsilon = 0.889120000000001
# Episode 56: total reward = -1, epsilon = 0.887140000000001
# Episode 57: total reward = -2, epsilon = 0.8851600000000011
# Episode 58: total reward = -3, epsilon = 0.8831800000000011
# Episode 59: total reward = -2, epsilon = 0.8812000000000011
# Episode 60: total reward = -3, epsilon = 0.8792200000000011
# Episode 61: total reward = -1, epsilon = 0.8772400000000011
# Episode 62: total reward = 0, epsilon = 0.8752600000000011
# Episode 63: total reward = -4, epsilon = 0.8732800000000012
# Episode 64: total reward = -4, epsilon = 0.8713000000000012
# Episode 65: total reward = -4, epsilon = 0.8693200000000012
# Episode 66: total reward = -5, epsilon = 0.8673400000000012
# Episode 67: total reward = 1, epsilon = 0.8653600000000012
# Episode 68: total reward = -3, epsilon = 0.8633800000000013
# Episode 69: total reward = 1, epsilon = 0.8614000000000013
# Episode 70: total reward = -4, epsilon = 0.8594200000000013
# Episode 71: total reward = -2, epsilon = 0.8574400000000013
# Episode 72: total reward = -1, epsilon = 0.8554600000000013
# Episode 73: total reward = -5, epsilon = 0.8534800000000013
# Episode 74: total reward = -1, epsilon = 0.8515000000000014
# Episode 75: total reward = 0, epsilon = 0.8495200000000014
# Episode 76: total reward = 0, epsilon = 0.8475400000000014
# Episode 77: total reward = 1, epsilon = 0.8455600000000014
# Episode 78: total reward = -1, epsilon = 0.8435800000000014
# Episode 79: total reward = 0, epsilon = 0.8416000000000015
# Episode 80: total reward = 0, epsilon = 0.8396200000000015
# Episode 81: total reward = -1, epsilon = 0.8376400000000015
# Episode 82: total reward = 0, epsilon = 0.8356600000000015
# Episode 83: total reward = 0, epsilon = 0.8336800000000015
# Episode 84: total reward = 0, epsilon = 0.8317000000000015
# Episode 85: total reward = 1, epsilon = 0.8297200000000016
# Episode 86: total reward = -3, epsilon = 0.8277400000000016
# Episode 87: total reward = -2, epsilon = 0.8257600000000016
# Episode 88: total reward = 0, epsilon = 0.8237800000000016
# Episode 89: total reward = -2, epsilon = 0.8218000000000016
# Episode 90: total reward = -1, epsilon = 0.8198200000000017
# Episode 91: total reward = -1, epsilon = 0.8178400000000017
# Episode 92: total reward = -5, epsilon = 0.8158600000000017
# Episode 93: total reward = 1, epsilon = 0.8138800000000017
# Episode 94: total reward = -1, epsilon = 0.8119000000000017
# Episode 95: total reward = -1, epsilon = 0.8099200000000017
# Episode 96: total reward = 1, epsilon = 0.8079400000000018
# Episode 97: total reward = -3, epsilon = 0.8059600000000018
# Episode 98: total reward = -11, epsilon = 0.8039800000000018
# Episode 99: total reward = 1, epsilon = 0.8020000000000018
# Episode 100: total reward = 1, epsilon = 0.8000200000000018
# Episode 101: total reward = 0, epsilon = 0.7980400000000019
# Episode 102: total reward = 0, epsilon = 0.7960600000000019
# Episode 103: total reward = -7, epsilon = 0.7940800000000019
# Episode 104: total reward = -2, epsilon = 0.7921000000000019
# Episode 105: total reward = 1, epsilon = 0.7901200000000019
# Episode 106: total reward = 1, epsilon = 0.788140000000002
# Episode 107: total reward = 1, epsilon = 0.786160000000002
# Episode 108: total reward = 0, epsilon = 0.784180000000002
# Episode 109: total reward = 1, epsilon = 0.782200000000002
# Episode 110: total reward = -1, epsilon = 0.780220000000002
# Episode 111: total reward = -1, epsilon = 0.778240000000002
# Episode 112: total reward = -2, epsilon = 0.7762600000000021
# Episode 113: total reward = 0, epsilon = 0.7742800000000021
# Episode 114: total reward = 0, epsilon = 0.7723000000000021
# Episode 115: total reward = -4, epsilon = 0.7703200000000021
# Episode 116: total reward = 0, epsilon = 0.7683400000000021
# Episode 117: total reward = -2, epsilon = 0.7663600000000022
# Episode 118: total reward = 0, epsilon = 0.7643800000000022
# Episode 119: total reward = -1, epsilon = 0.7624000000000022
# Episode 120: total reward = -2, epsilon = 0.7604200000000022
# Episode 121: total reward = 0, epsilon = 0.7584400000000022
# Episode 122: total reward = 0, epsilon = 0.7564600000000022
# Episode 123: total reward = 1, epsilon = 0.7544800000000023
# Episode 124: total reward = -1, epsilon = 0.7525000000000023
# Episode 125: total reward = -2, epsilon = 0.7505200000000023
# Episode 126: total reward = 1, epsilon = 0.7485400000000023
# Episode 127: total reward = -1, epsilon = 0.7465600000000023
# Episode 128: total reward = -1, epsilon = 0.7445800000000024
# Episode 129: total reward = 0, epsilon = 0.7426000000000024
# Episode 130: total reward = -2, epsilon = 0.7406200000000024
# Episode 131: total reward = -2, epsilon = 0.7386400000000024
# Episode 132: total reward = 1, epsilon = 0.7366600000000024
# Episode 133: total reward = -3, epsilon = 0.7346800000000024
# Episode 134: total reward = -2, epsilon = 0.7327000000000025
# Episode 509: total reward = 1, epsilon = 0.01
# Episode 510: total reward = 1, epsilon = 0.01
# Episode 511: total reward = 1, epsilon = 0.01
# Episode 512: total reward = 1, epsilon = 0.01
# Episode 513: total reward = 1, epsilon = 0.01
# Episode 514: total reward = 1, epsilon = 0.01
# Episode 515: total reward = 1, epsilon = 0.01
# Episode 516: total reward = 1, epsilon = 0.01
# Episode 517: total reward = 1, epsilon = 0.01
# Episode 518: total reward = 1, epsilon = 0.01
# Episode 519: total reward = 1, epsilon = 0.01
# Episode 520: total reward = 1, epsilon = 0.01
# Episode 521: total reward = 1, epsilon = 0.01
# Episode 522: total reward = 1, epsilon = 0.01
# Episode 523: total reward = 1, epsilon = 0.01
# Episode 524: total reward = 1, epsilon = 0.01
# Episode 525: total reward = 1, epsilon = 0.01
# Episode 526: total reward = 1, epsilon = 0.01
# Episode 527: total reward = 1, epsilon = 0.01
# Episode 528: total reward = 1, epsilon = 0.01
# Episode 529: total reward = 1, epsilon = 0.01
# Episode 530: total reward = 1, epsilon = 0.01
# Episode 531: total reward = 1, epsilon = 0.01
# Episode 532: total reward = 1, epsilon = 0.01
# Episode 533: total reward = 1, epsilon = 0.01
# Episode 534: total reward = 1, epsilon = 0.01
# Episode 535: total reward = 1, epsilon = 0.01
# Episode 536: total reward = 1, epsilon = 0.01
# Episode 537: total reward = 1, epsilon = 0.01
# Episode 538: total reward = 1, epsilon = 0.01
# Episode 539: total reward = 1, epsilon = 0.01
# Episode 540: total reward = 1, epsilon = 0.01
# Episode 541: total reward = 1, epsilon = 0.01
# Episode 542: total reward = 1, epsilon = 0.01
# Episode 543: total reward = 1, epsilon = 0.01
# Episode 544: total reward = 1, epsilon = 0.01
# Episode 545: total reward = 1, epsilon = 0.01
# Episode 546: total reward = 1, epsilon = 0.01
# Episode 547: total reward = 1, epsilon = 0.01
# Episode 548: total reward = 1, epsilon = 0.01
# Episode 549: total reward = 1, epsilon = 0.01
# Episode 550: total reward = 1, epsilon = 0.01
# Episode 551: total reward = 1, epsilon = 0.01
# Episode 552: total reward = 1, epsilon = 0.01
# Episode 553: total reward = 1, epsilon = 0.01
# Episode 554: total reward = 1, epsilon = 0.01
# Episode 555: total reward = 1, epsilon = 0.01
# Episode 556: total reward = 1, epsilon = 0.01
# Episode 557: total reward = 1, epsilon = 0.01
# Episode 558: total reward = 1, epsilon = 0.01
# Episode 559: total reward = 1, epsilon = 0.01
# Episode 560: total reward = 1, epsilon = 0.01
# Episode 561: total reward = 1, epsilon = 0.01
# Episode 562: total reward = 1, epsilon = 0.01
# Episode 563: total reward = 1, epsilon = 0.01
# Episode 564: total reward = 1, epsilon = 0.01
# Episode 565: total reward = 1, epsilon = 0.01
# Episode 566: total reward = 1, epsilon = 0.01
# Episode 567: total reward = 1, epsilon = 0.01
# Episode 568: total reward = 1, epsilon = 0.01
# Episode 569: total reward = 1, epsilon = 0.01
# Episode 570: total reward = 1, epsilon = 0.01
# Episode 571: total reward = 1, epsilon = 0.01
# Episode 572: total reward = 1, epsilon = 0.01
# Episode 573: total reward = 1, epsilon = 0.01
# Episode 574: total reward = 1, epsilon = 0.01
# Episode 575: total reward = 1, epsilon = 0.01
# Episode 576: total reward = 1, epsilon = 0.01
# Episode 577: total reward = 1, epsilon = 0.01
# Episode 578: total reward = 1, epsilon = 0.01
# Episode 579: total reward = 1, epsilon = 0.01
# Episode 580: total reward = 1, epsilon = 0.01
# Episode 581: total reward = 1, epsilon = 0.01
# Episode 582: total reward = 1, epsilon = 0.01
# Episode 583: total reward = 1, epsilon = 0.01
# Episode 584: total reward = 1, epsilon = 0.01
# Episode 585: total reward = 1, epsilon = 0.01
# Episode 586: total reward = 1, epsilon = 0.01
# Episode 587: total reward = 1, epsilon = 0.01
# Episode 588: total reward = 1, epsilon = 0.01
# Episode 589: total reward = 1, epsilon = 0.01
# Episode 590: total reward = 1, epsilon = 0.01
# Episode 591: total reward = 0, epsilon = 0.01
# Episode 592: total reward = 1, epsilon = 0.01
# Episode 593: total reward = 1, epsilon = 0.01
# Episode 594: total reward = 1, epsilon = 0.01
# Episode 595: total reward = 1, epsilon = 0.01
# Episode 596: total reward = 1, epsilon = 0.01
# Episode 597: total reward = 1, epsilon = 0.01
# Episode 598: total reward = 1, epsilon = 0.01
# Episode 599: total reward = 1, epsilon = 0.01
# Episode 600: total reward = 1, epsilon = 0.01
# Episode 601: total reward = 1, epsilon = 0.01
# Episode 602: total reward = 1, epsilon = 0.01
# Episode 603: total reward = 1, epsilon = 0.01
# Episode 604: total reward = 1, epsilon = 0.01
# Episode 605: total reward = 1, epsilon = 0.01
# Episode 606: total reward = 1, epsilon = 0.01
# Episode 607: total reward = 1, epsilon = 0.01
# Episode 608: total reward = 1, epsilon = 0.01
# Episode 609: total reward = 1, epsilon = 0.01
# Episode 610: total reward = 1, epsilon = 0.01
# Episode 611: total reward = 1, epsilon = 0.01
# Episode 612: total reward = 1, epsilon = 0.01
# Episode 613: total reward = 1, epsilon = 0.01
# Episode 614: total reward = 1, epsilon = 0.01
# Episode 615: total reward = 1, epsilon = 0.01
# Episode 616: total reward = 1, epsilon = 0.01
# Episode 617: total reward = 1, epsilon = 0.01
# Episode 618: total reward = 0, epsilon = 0.01
# Episode 619: total reward = 1, epsilon = 0.01
# Episode 620: total reward = 1, epsilon = 0.01
# Episode 621: total reward = 1, epsilon = 0.01
# Episode 622: total reward = 1, epsilon = 0.01
# Episode 623: total reward = 1, epsilon = 0.01
# Episode 624: total reward = 1, epsilon = 0.01
# Episode 625: total reward = 1, epsilon = 0.01
# Episode 626: total reward = 1, epsilon = 0.01
# Episode 627: total reward = 1, epsilon = 0.01
# Episode 628: total reward = 1, epsilon = 0.01
# Episode 629: total reward = 1, epsilon = 0.01
# Episode 630: total reward = 1, epsilon = 0.01
# Episode 631: total reward = 1, epsilon = 0.01
# Episode 632: total reward = 1, epsilon = 0.01
# Episode 633: total reward = 1, epsilon = 0.01
# Episode 634: total reward = 1, epsilon = 0.01
# Episode 635: total reward = 1, epsilon = 0.01
# Episode 636: total reward = 1, epsilon = 0.01
# Episode 637: total reward = 1, epsilon = 0.01
# Episode 638: total reward = 1, epsilon = 0.01
# Episode 639: total reward = 1, epsilon = 0.01
# Episode 640: total reward = 1, epsilon = 0.01
# Episode 641: total reward = 1, epsilon = 0.01
# Episode 642: total reward = 1, epsilon = 0.01
# Episode 643: total reward = 1, epsilon = 0.01
# Episode 644: total reward = 1, epsilon = 0.01
# Episode 645: total reward = 1, epsilon = 0.01
# Episode 646: total reward = 1, epsilon = 0.01
# Episode 647: total reward = 1, epsilon = 0.01
# Episode 648: total reward = 1, epsilon = 0.01
# Episode 649: total reward = 1, epsilon = 0.01
# Episode 650: total reward = 1, epsilon = 0.01
# Episode 651: total reward = 1, epsilon = 0.01
# Episode 652: total reward = 1, epsilon = 0.01
# Episode 653: total reward = 1, epsilon = 0.01
# Episode 654: total reward = 1, epsilon = 0.01
# Episode 655: total reward = 1, epsilon = 0.01
# Episode 656: total reward = 1, epsilon = 0.01
# Episode 657: total reward = 1, epsilon = 0.01
# Episode 658: total reward = 1, epsilon = 0.01
# Episode 659: total reward = 1, epsilon = 0.01
# Episode 660: total reward = 1, epsilon = 0.01
# Episode 661: total reward = 1, epsilon = 0.01
# Episode 662: total reward = 1, epsilon = 0.01
# Episode 663: total reward = 1, epsilon = 0.01
# Episode 664: total reward = 1, epsilon = 0.01
# Episode 665: total reward = 1, epsilon = 0.01
# Episode 666: total reward = 1, epsilon = 0.01
# Episode 667: total reward = 1, epsilon = 0.01
# Episode 668: total reward = 1, epsilon = 0.01
# Episode 669: total reward = 1, epsilon = 0.01
# Episode 670: total reward = 1, epsilon = 0.01
# Episode 671: total reward = 1, epsilon = 0.01
# Episode 672: total reward = 1, epsilon = 0.01
# Episode 673: total reward = 1, epsilon = 0.01
# Episode 674: total reward = 1, epsilon = 0.01
# Episode 675: total reward = 1, epsilon = 0.01
# Episode 676: total reward = 1, epsilon = 0.01
# Episode 677: total reward = 1, epsilon = 0.01
# Episode 678: total reward = 1, epsilon = 0.01
# Episode 679: total reward = 1, epsilon = 0.01
# Episode 680: total reward = 1, epsilon = 0.01
# Episode 681: total reward = 1, epsilon = 0.01
# Episode 682: total reward = 1, epsilon = 0.01
# Episode 683: total reward = 1, epsilon = 0.01
# Episode 684: total reward = 1, epsilon = 0.01
# Episode 685: total reward = 1, epsilon = 0.01
# Episode 686: total reward = 1, epsilon = 0.01
# Episode 687: total reward = 1, epsilon = 0.01
# Episode 688: total reward = 1, epsilon = 0.01
# Episode 689: total reward = 1, epsilon = 0.01
# Episode 690: total reward = 1, epsilon = 0.01
# Episode 691: total reward = 1, epsilon = 0.01
# Episode 692: total reward = 1, epsilon = 0.01
# Episode 693: total reward = 1, epsilon = 0.01
# Episode 694: total reward = 1, epsilon = 0.01
# Episode 695: total reward = 1, epsilon = 0.01
# Episode 696: total reward = 1, epsilon = 0.01
# Episode 697: total reward = 1, epsilon = 0.01
# Episode 698: total reward = 1, epsilon = 0.01
# Episode 699: total reward = 1, epsilon = 0.01
# Episode 700: total reward = 1, epsilon = 0.01
# Episode 701: total reward = 1, epsilon = 0.01
# Episode 702: total reward = 1, epsilon = 0.01
# Episode 703: total reward = 1, epsilon = 0.01
# Episode 704: total reward = 1, epsilon = 0.01
# Episode 705: total reward = 1, epsilon = 0.01
# Episode 706: total reward = 1, epsilon = 0.01
# Episode 707: total reward = 1, epsilon = 0.01
# Episode 708: total reward = 1, epsilon = 0.01
# Episode 709: total reward = 1, epsilon = 0.01
# Episode 710: total reward = 1, epsilon = 0.01
# Episode 711: total reward = 1, epsilon = 0.01
# Episode 712: total reward = 1, epsilon = 0.01
# Episode 713: total reward = 1, epsilon = 0.01
# Episode 714: total reward = 1, epsilon = 0.01
# Episode 715: total reward = 1, epsilon = 0.01
# Episode 716: total reward = 1, epsilon = 0.01
# Episode 717: total reward = 1, epsilon = 0.01
# Episode 718: total reward = 1, epsilon = 0.01
# Episode 719: total reward = 1, epsilon = 0.01
# Episode 720: total reward = 1, epsilon = 0.01
# Episode 721: total reward = 1, epsilon = 0.01
# Episode 722: total reward = 1, epsilon = 0.01
# Episode 723: total reward = 1, epsilon = 0.01
# Episode 724: total reward = 1, epsilon = 0.01
# Episode 725: total reward = 1, epsilon = 0.01
# Episode 726: total reward = 1, epsilon = 0.01
# Episode 727: total reward = 1, epsilon = 0.01
# Episode 728: total reward = 1, epsilon = 0.01
# Episode 729: total reward = 1, epsilon = 0.01
# Episode 730: total reward = 1, epsilon = 0.01
# Episode 731: total reward = 1, epsilon = 0.01
# Episode 732: total reward = 1, epsilon = 0.01
# Episode 733: total reward = 1, epsilon = 0.01
# Episode 734: total reward = 1, epsilon = 0.01
# Episode 735: total reward = 1, epsilon = 0.01
# Episode 736: total reward = 1, epsilon = 0.01
# Episode 737: total reward = 1, epsilon = 0.01
# Episode 738: total reward = 1, epsilon = 0.01
# Episode 739: total reward = 1, epsilon = 0.01
# Episode 740: total reward = 1, epsilon = 0.01
# Episode 741: total reward = 1, epsilon = 0.01
# Episode 742: total reward = 1, epsilon = 0.01
# Episode 743: total reward = 1, epsilon = 0.01
# Episode 744: total reward = 1, epsilon = 0.01
# Episode 745: total reward = 1, epsilon = 0.01
# Episode 746: total reward = 1, epsilon = 0.01
# Episode 747: total reward = 1, epsilon = 0.01
# Episode 748: total reward = 1, epsilon = 0.01
# Episode 749: total reward = 1, epsilon = 0.01
# Episode 750: total reward = 1, epsilon = 0.01
# Episode 751: total reward = 1, epsilon = 0.01
# Episode 752: total reward = 1, epsilon = 0.01
# Episode 753: total reward = 1, epsilon = 0.01
# Episode 754: total reward = 1, epsilon = 0.01
# Episode 755: total reward = 1, epsilon = 0.01
# Episode 756: total reward = 1, epsilon = 0.01
# Episode 757: total reward = 1, epsilon = 0.01
# Episode 758: total reward = 1, epsilon = 0.01
# Episode 759: total reward = 1, epsilon = 0.01
# Episode 760: total reward = 1, epsilon = 0.01
# Episode 761: total reward = 1, epsilon = 0.01
# Episode 762: total reward = 1, epsilon = 0.01
# Episode 763: total reward = 1, epsilon = 0.01
# Episode 764: total reward = 1, epsilon = 0.01
# Episode 765: total reward = 1, epsilon = 0.01
# Episode 766: total reward = 1, epsilon = 0.01
# Episode 767: total reward = 1, epsilon = 0.01
# Episode 768: total reward = 1, epsilon = 0.01
# Episode 769: total reward = 1, epsilon = 0.01
# Episode 770: total reward = 1, epsilon = 0.01
# Episode 771: total reward = 1, epsilon = 0.01
# Episode 772: total reward = 1, epsilon = 0.01
# Episode 773: total reward = 1, epsilon = 0.01
# Episode 774: total reward = 1, epsilon = 0.01
# Episode 775: total reward = 1, epsilon = 0.01
# Episode 776: total reward = 1, epsilon = 0.01
# Episode 777: total reward = 1, epsilon = 0.01
# Episode 778: total reward = 1, epsilon = 0.01
# Episode 779: total reward = 1, epsilon = 0.01
# Episode 780: total reward = 1, epsilon = 0.01
# Episode 781: total reward = 1, epsilon = 0.01
# Episode 782: total reward = 1, epsilon = 0.01
# Episode 783: total reward = 1, epsilon = 0.01
# Episode 784: total reward = 1, epsilon = 0.01
# Episode 785: total reward = 1, epsilon = 0.01
# Episode 786: total reward = 1, epsilon = 0.01
# Episode 787: total reward = 1, epsilon = 0.01
# Episode 788: total reward = 1, epsilon = 0.01
# Episode 789: total reward = 1, epsilon = 0.01
# Episode 790: total reward = 1, epsilon = 0.01
# Episode 791: total reward = 1, epsilon = 0.01
# Episode 792: total reward = 1, epsilon = 0.01
# Episode 793: total reward = 1, epsilon = 0.01
# Episode 794: total reward = 1, epsilon = 0.01
# Episode 795: total reward = 1, epsilon = 0.01
# Episode 796: total reward = 1, epsilon = 0.01
# Episode 797: total reward = 1, epsilon = 0.01
# Episode 798: total reward = 1, epsilon = 0.01
# Episode 799: total reward = 1, epsilon = 0.01
# Episode 800: total reward = 1, epsilon = 0.01
# Episode 801: total reward = 1, epsilon = 0.01
# Episode 802: total reward = 1, epsilon = 0.01
# Episode 803: total reward = 1, epsilon = 0.01
# Episode 804: total reward = 1, epsilon = 0.01
# Episode 805: total reward = 1, epsilon = 0.01
# Episode 806: total reward = 1, epsilon = 0.01
# Episode 807: total reward = 1, epsilon = 0.01
# Episode 808: total reward = 1, epsilon = 0.01
# Episode 809: total reward = 1, epsilon = 0.01
# Episode 810: total reward = 1, epsilon = 0.01
# Episode 811: total reward = 1, epsilon = 0.01
# Episode 812: total reward = 1, epsilon = 0.01
# Episode 813: total reward = 1, epsilon = 0.01
# Episode 814: total reward = 1, epsilon = 0.01
# Episode 815: total reward = 1, epsilon = 0.01
# Episode 816: total reward = 1, epsilon = 0.01
# Episode 817: total reward = 1, epsilon = 0.01
# Episode 818: total reward = 1, epsilon = 0.01
# Episode 819: total reward = 1, epsilon = 0.01
# Episode 820: total reward = 1, epsilon = 0.01
# Episode 821: total reward = 1, epsilon = 0.01
# Episode 822: total reward = 1, epsilon = 0.01
# Episode 823: total reward = 1, epsilon = 0.01
# Episode 824: total reward = 1, epsilon = 0.01
# Episode 825: total reward = 1, epsilon = 0.01
# Episode 826: total reward = 1, epsilon = 0.01
# Episode 827: total reward = 1, epsilon = 0.01
# Episode 828: total reward = 0, epsilon = 0.01
# Episode 829: total reward = 1, epsilon = 0.01
# Episode 830: total reward = 1, epsilon = 0.01
# Episode 831: total reward = 1, epsilon = 0.01
# Episode 832: total reward = 1, epsilon = 0.01
# Episode 833: total reward = 1, epsilon = 0.01
# Episode 834: total reward = 1, epsilon = 0.01
# Episode 835: total reward = 1, epsilon = 0.01
# Episode 836: total reward = 1, epsilon = 0.01
# Episode 837: total reward = 1, epsilon = 0.01
# Episode 838: total reward = 1, epsilon = 0.01
# Episode 839: total reward = 1, epsilon = 0.01
# Episode 840: total reward = 1, epsilon = 0.01
# Episode 841: total reward = 1, epsilon = 0.01
# Episode 842: total reward = 1, epsilon = 0.01
# Episode 843: total reward = 1, epsilon = 0.01
# Episode 844: total reward = 1, epsilon = 0.01
# Episode 845: total reward = 1, epsilon = 0.01
# Episode 846: total reward = 1, epsilon = 0.01
# Episode 847: total reward = 1, epsilon = 0.01
# Episode 848: total reward = 1, epsilon = 0.01
# Episode 849: total reward = 1, epsilon = 0.01
# Episode 850: total reward = 1, epsilon = 0.01
# Episode 851: total reward = 1, epsilon = 0.01
# Episode 852: total reward = 1, epsilon = 0.01
# Episode 853: total reward = 1, epsilon = 0.01
# Episode 854: total reward = 1, epsilon = 0.01
# Episode 855: total reward = 1, epsilon = 0.01
# Episode 856: total reward = 1, epsilon = 0.01
# Episode 857: total reward = 1, epsilon = 0.01
# Episode 858: total reward = 1, epsilon = 0.01
# Episode 859: total reward = 1, epsilon = 0.01
# Episode 860: total reward = 1, epsilon = 0.01
# Episode 861: total reward = 1, epsilon = 0.01
# Episode 862: total reward = 1, epsilon = 0.01
# Episode 863: total reward = 1, epsilon = 0.01
# Episode 864: total reward = 1, epsilon = 0.01
# Episode 865: total reward = 1, epsilon = 0.01
# Episode 866: total reward = 1, epsilon = 0.01
# Episode 867: total reward = 1, epsilon = 0.01
# Episode 868: total reward = 1, epsilon = 0.01
# Episode 869: total reward = 1, epsilon = 0.01
# Episode 870: total reward = 1, epsilon = 0.01
# Episode 871: total reward = 1, epsilon = 0.01
# Episode 872: total reward = 1, epsilon = 0.01
# Episode 873: total reward = 1, epsilon = 0.01
# Episode 874: total reward = 1, epsilon = 0.01
# Episode 875: total reward = 1, epsilon = 0.01
# Episode 876: total reward = 1, epsilon = 0.01
# Episode 877: total reward = 1, epsilon = 0.01
# Episode 878: total reward = 1, epsilon = 0.01
# Episode 879: total reward = 1, epsilon = 0.01
# Episode 880: total reward = 1, epsilon = 0.01
# Episode 881: total reward = 1, epsilon = 0.01
# Episode 882: total reward = 1, epsilon = 0.01
# Episode 883: total reward = 1, epsilon = 0.01
# Episode 884: total reward = 1, epsilon = 0.01
# Episode 885: total reward = 1, epsilon = 0.01
# Episode 886: total reward = 1, epsilon = 0.01
# Episode 887: total reward = 1, epsilon = 0.01
# Episode 888: total reward = 1, epsilon = 0.01
# Episode 889: total reward = 1, epsilon = 0.01
# Episode 890: total reward = 1, epsilon = 0.01
# Episode 891: total reward = 1, epsilon = 0.01
# Episode 892: total reward = 1, epsilon = 0.01
# Episode 893: total reward = 1, epsilon = 0.01
# Episode 894: total reward = 1, epsilon = 0.01
# Episode 895: total reward = 1, epsilon = 0.01
# Episode 896: total reward = 1, epsilon = 0.01
# Episode 897: total reward = 1, epsilon = 0.01
# Episode 898: total reward = 1, epsilon = 0.01
# Episode 899: total reward = 1, epsilon = 0.01
# Episode 900: total reward = 1, epsilon = 0.01
# Episode 901: total reward = 1, epsilon = 0.01
# Episode 902: total reward = 1, epsilon = 0.01
# Episode 903: total reward = 1, epsilon = 0.01
# Episode 904: total reward = 1, epsilon = 0.01
# Episode 905: total reward = 1, epsilon = 0.01
# Episode 906: total reward = 1, epsilon = 0.01
# Episode 907: total reward = 1, epsilon = 0.01
# Episode 908: total reward = 1, epsilon = 0.01
# Episode 909: total reward = 1, epsilon = 0.01
# Episode 910: total reward = 1, epsilon = 0.01
# Episode 911: total reward = 1, epsilon = 0.01
# Episode 912: total reward = 1, epsilon = 0.01
# Episode 913: total reward = 1, epsilon = 0.01
# Episode 914: total reward = 1, epsilon = 0.01
# Episode 915: total reward = 1, epsilon = 0.01
# Episode 916: total reward = 1, epsilon = 0.01
# Episode 917: total reward = 1, epsilon = 0.01
# Episode 918: total reward = 1, epsilon = 0.01
# Episode 919: total reward = 1, epsilon = 0.01
# Episode 920: total reward = 1, epsilon = 0.01
# Episode 921: total reward = 1, epsilon = 0.01
# Episode 922: total reward = 1, epsilon = 0.01
# Episode 923: total reward = 1, epsilon = 0.01
# Episode 924: total reward = 1, epsilon = 0.01
# Episode 925: total reward = 1, epsilon = 0.01
# Episode 926: total reward = 1, epsilon = 0.01
# Episode 927: total reward = 1, epsilon = 0.01
# Episode 928: total reward = 1, epsilon = 0.01
# Episode 929: total reward = 1, epsilon = 0.01
# Episode 930: total reward = 1, epsilon = 0.01
# Episode 931: total reward = 1, epsilon = 0.01
# Episode 932: total reward = 1, epsilon = 0.01
# Episode 933: total reward = 1, epsilon = 0.01
# Episode 934: total reward = 1, epsilon = 0.01
# Episode 935: total reward = 1, epsilon = 0.01
# Episode 936: total reward = 1, epsilon = 0.01
# Episode 937: total reward = 1, epsilon = 0.01
# Episode 938: total reward = 1, epsilon = 0.01
# Episode 939: total reward = 1, epsilon = 0.01
# Episode 940: total reward = 1, epsilon = 0.01
# Episode 941: total reward = 1, epsilon = 0.01
# Episode 942: total reward = 1, epsilon = 0.01
# Episode 943: total reward = 1, epsilon = 0.01
# Episode 944: total reward = 1, epsilon = 0.01
# Episode 945: total reward = 1, epsilon = 0.01
# Episode 946: total reward = 1, epsilon = 0.01
# Episode 947: total reward = 1, epsilon = 0.01
# Episode 948: total reward = 1, epsilon = 0.01
# Episode 949: total reward = 1, epsilon = 0.01
# Episode 950: total reward = 1, epsilon = 0.01
# Episode 951: total reward = 1, epsilon = 0.01
# Episode 952: total reward = 1, epsilon = 0.01
# Episode 953: total reward = 1, epsilon = 0.01
# Episode 954: total reward = 1, epsilon = 0.01
# Episode 955: total reward = 1, epsilon = 0.01
# Episode 956: total reward = 1, epsilon = 0.01
# Episode 957: total reward = 1, epsilon = 0.01
# Episode 958: total reward = 1, epsilon = 0.01
# Episode 959: total reward = 1, epsilon = 0.01
# Episode 960: total reward = 1, epsilon = 0.01
# Episode 961: total reward = 1, epsilon = 0.01
# Episode 962: total reward = 1, epsilon = 0.01
# Episode 963: total reward = 1, epsilon = 0.01
# Episode 964: total reward = 1, epsilon = 0.01
# Episode 965: total reward = 1, epsilon = 0.01
# Episode 966: total reward = 1, epsilon = 0.01
# Episode 967: total reward = 1, epsilon = 0.01
# Episode 968: total reward = 1, epsilon = 0.01
# Episode 969: total reward = 1, epsilon = 0.01
# Episode 970: total reward = 1, epsilon = 0.01
# Episode 971: total reward = 1, epsilon = 0.01
# Episode 972: total reward = 1, epsilon = 0.01
# Episode 973: total reward = 1, epsilon = 0.01
# Episode 974: total reward = 1, epsilon = 0.01
# Episode 975: total reward = 1, epsilon = 0.01
# Episode 976: total reward = 1, epsilon = 0.01
# Episode 977: total reward = 1, epsilon = 0.01
# Episode 978: total reward = 1, epsilon = 0.01
# Episode 979: total reward = 1, epsilon = 0.01
# Episode 980: total reward = 1, epsilon = 0.01
# Episode 981: total reward = 1, epsilon = 0.01
# Episode 982: total reward = 1, epsilon = 0.01
# Episode 983: total reward = 1, epsilon = 0.01
# Episode 984: total reward = 1, epsilon = 0.01
# Episode 985: total reward = 1, epsilon = 0.01
# Episode 986: total reward = 1, epsilon = 0.01
# Episode 987: total reward = 1, epsilon = 0.01
# Episode 988: total reward = 1, epsilon = 0.01
# Episode 989: total reward = 1, epsilon = 0.01
# Episode 990: total reward = 1, epsilon = 0.01
# Episode 991: total reward = 1, epsilon = 0.01
# Episode 992: total reward = 1, epsilon = 0.01
# Episode 993: total reward = 1, epsilon = 0.01
# Episode 994: total reward = 1, epsilon = 0.01
# Episode 995: total reward = 1, epsilon = 0.01
# Episode 996: total reward = 1, epsilon = 0.01
# Episode 997: total reward = 1, epsilon = 0.01
# Episode 998: total reward = 1, epsilon = 0.01
# Episode 999: total reward = 1, epsilon = 0.01

# %% [markdown]
# ---
# ### Q-learning (off-policy TD control) for estimating $\pi \approx \pi∗$
#
# Algorithm parameters: step size $\alpha \in (0, 1]$, small $\epsilon > 0$ <br>
# Initialize $Q(s, a)$, for all $s \in S^+$, $a \in A(s)$, arbitrarily except that $Q(terminal , ·) = 0$
#
# Loop for each episode:
# - Initialize $S$ <br>
# - Loop for each step of episode: <br>
#     - Choose $A$ from $S$ using policy derived from $Q$ (e.g., $\epsilon$-greedy)<br>
#     - Take action $A$, observe $R, S′$<br>
#     - $Q(S, A) \gets Q(S, A) + \alpha \Big[R + γ max_a Q(S′, a) − Q(S, A)\Big]$
#     - $S \gets S′$
# - until $S$ is terminal
# ---

# %% [markdown]
# ## Further Ideas
#
# - experiment with different exploration settings!
# - compare the performance of your agent against a random agent.
# - implement a "play" only loop/method that can take the learned value function.
#
# (only if good in time, if not, better start with the next notebook)
#
# - experiment with different hyperparameters and compare your results in a proper data visualisation.
# - read and/or reason about potentiall shortcomings/improvements/efficiency etc. and write down your thoughts.
# - experiment with exitgames level 1.
#
# ## Next: PIA - Reinforcement Learning: 4. Deep Reinforcement Learning (DQN)
